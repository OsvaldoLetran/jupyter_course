# %% [markdown]
# # Polinomios de hermite y sus graficas

# %% [markdown]
# ## Polinomios

# %%
from sympy import *
import sympy as sym

x, y, z, t = symbols('x y z t')

# %%
from sympy.plotting import plot
from sympy import init_printing
init_printing(use_latex=True)
import sympy as sp
for n in [0,1,2,3]:
    display(hermite(n,x))
# Out:
# 1
# 2⋅x
#    2
# 4⋅x  - 2
#    3
# 8⋅x  - 12⋅x

# %%
def Hn(n):
    return hermite(n,x)

# %%
Hn(4)
# Out:
#     4       2
# 16⋅x  - 48⋅x  + 12

# %%
h0 = hermite(0,x)
h0
plot(h0)

# %%
h1 = hermite(1,x)
h1
plot(h1)

# %%
h2 = hermite(2,x)
h2
plot(h2)

# %%
h3 = hermite(3,x)
h3
plot(h3)
